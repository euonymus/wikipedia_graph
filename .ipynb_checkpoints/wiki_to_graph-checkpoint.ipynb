# %%
# https://qiita.com/musaprg/items/9a572ad5c4e28f79d2ae
# import MeCab
# tagger = MeCab.Tagger("-Ochasen")
# tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd")
# print(tagger.parse("幼稚園でいっぱいいろんな歌を歌っているね"))

# %%
# https://kakubari-ryusei.hatenablog.com/entry/2017/10/04/192447
# import CaboCha
# cabocha = CaboCha.Parser()
# sentence = "幼稚園でいっぱいいろんな歌を歌っているね"
# tree = cabocha.parse(sentence)
# print(tree.toString(CaboCha.CABOCHA_FORMAT_TREE))

# %%
from neo4j import GraphDatabase
NEO4J_URL = "bolt://localhost:7687"
NEO4J_ID = "neo4j"
NEO4J_PW = "password"

class Neo4jRepository(object):

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self._driver.close()

    def create_node(self, name, label):
        with self._driver.session() as session:
            result = session.write_transaction(self._merge_and_return_node, name, label)
        return result

    def delete_node(self, name, label):
        with self._driver.session() as session:
            result = session.write_transaction(self._delete_and_return_node, name, label)
        return result

    @staticmethod
    def _merge_and_return_node(tx, name, label):
        result = tx.run("MERGE (n:%s {name: $name}) RETURN n" % (label), name=name)
        return result.single()[0]

    @staticmethod
    def _delete_and_return_node(tx, name, label):
        result = tx.run("MATCH (n:%s {name: $name}) DETACH DELETE n RETURN n" % (label), name=name)
        return result.single()[0]

# %%
import MeCab
tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd")

LABEL_THING = 'Thing'
LABEL_PERSON = 'Person'
LABEL_ORGANIZATION = 'Organization'
LABEL_AREA = 'Area'
LABEL_COUNTRY = 'Country'

def paragraph_to_list(paragraph):
    return paragraph.split('\n')
def paragraph_to_mecab_morphemes(paragraph):
    return paragraph_to_list(tagger.parse(paragraph))
def mecab_morpheme_to_list(mecab_morpheme):
    tmp = mecab_morpheme.split('\t')
    if len(tmp) < 2:
        return False
    info = tmp[1].split(',')
    info.insert(0, tmp[0])
    return info

def paragraph_to_proper_nouns(paragraph):
    morphemes = paragraph_to_mecab_morphemes(paragraph)

    proper_nouns = []
    for line in morphemes:
        morpheme = mecab_morpheme_to_list(line)
        if not morpheme:
            continue
        if morpheme[2] == '固有名詞':
            if morpheme[3] == '人名':
                if morpheme[4] != '一般':
                    continue
                label = LABEL_PERSON
            elif morpheme[3] == '組織':
                label = LABEL_ORGANIZATION
            elif morpheme[3] == '地域':
                if morpheme[4] == '国':
                    label = LABEL_COUNTRY
                else:
                    label = LABEL_AREA
            else:
                label = LABEL_THING
            proper_nouns.append({'name': morpheme[0], 'label': label})
    return proper_nouns

# %%
import re

def delete_brackets(s):
    """
    括弧と括弧内文字列を削除
    """
    """ brackets to zenkaku """
    table = {
        "(": "（",
        ")": "）",
        "<": "＜",
        ">": "＞",
        "{": "｛",
        "}": "｝",
        "[": "［",
        "]": "］"
    }
    for key in table.keys():
        s = s.replace(key, table[key])
    """ delete zenkaku_brackets """
    l = ['（[^（|^）]*）', '【[^【|^】]*】', '＜[^＜|^＞]*＞', '［[^［|^］]*］',
         '「[^「|^」]*」', '｛[^｛|^｝]*｝', '〔[^〔|^〕]*〕', '〈[^〈|^〉]*〉']
    for l_ in l:
        s = re.sub(l_, "", s)
    """ recursive processing """
    return delete_brackets(s) if sum([1 if re.search(l_, s) else 0 for l_ in l]) > 0 else s

# %%
# https://qiita.com/poorko/items/9140c75415d748633a10
subject = '明仁'

# %%
import urllib
import requests
from bs4 import BeautifulSoup

encoded_subject = urllib.parse.quote(subject)
wikipedia_url = requests.get('https://ja.wikipedia.org/wiki/%s' % (encoded_subject))

# Get Html
soup = BeautifulSoup(wikipedia_url.content, 'lxml')

# Remove script and style attributes
for script in soup(["script", "style"]):
    script.decompose()

#print(soup.prettify)
# Get only Text
raw_text = soup.get_text()

# Put lines in a list
all_lines= [line.strip() for line in raw_text.splitlines()]

# Make the list into text without empty lines
all_text="\n".join(line for line in all_lines if line)

# Sanitize
sanitized_text = delete_brackets(all_text)

# Split into Sentences
import re
lines = re.findall(r'[^。]+(?:[。]|$)', sanitized_text)

# %%
node_origins = []
for sentence in lines:
    node_origins.extend(paragraph_to_proper_nouns(sentence))
print(node_origins)
# Out:
# [{'name': 'Wikipedia', 'label': 'Thing'}, {'name': '百科事典', 'label': 'Thing'}, {'name': 'ウィキペディア', 'label': 'Thing'}, {'name': 'ナビゲーション', 'label': 'Thing'}, {'name': '2014年', 'label': 'Thing'}, {'name': '4月24日', 'label': 'Thing'}, {'name': '1989年', 'label': 'Thing'}, {'name': '1月7日', 'label': 'Thing'}, {'name': '2019年', 'label': 'Thing'}, {'name': '4月30日', 'label': 'Thing'}, {'name': '昭和64年', 'label': 'Thing'}, {'name': '1月7日', 'label': 'Thing'}, {'name': '午前6時', 'label': 'Thing'}, {'name': '33分', 'label': 'Thing'}, {'name': '平成31年', 'label': 'Thing'}, {'name': '4月30日', 'label': 'Thing'}, {'name': '12時', 'label': 'Thing'}, {'name': '即位礼', 'label': 'Thing'}, {'name': '即位礼正殿の儀', 'label': 'Thing'}, {'name': '1990年', 'label': 'Thing'}, {'name': '11月12日', 'label': 'Thing'}, {'name': '大嘗宮の儀', 'label': 'Thing'}, {'name': '1990年', 'label': 'Thing'}, {'name': '11月22日', 'label': 'Thing'}, {'name': '23日', 'label': 'Thing'}, {'name': '東御苑', 'label': 'Area'}, {'name': '大嘗宮', 'label': 'Thing'}, {'name': '昭和', 'label': 'Thing'}, {'name': '1989年', 'label': 'Thing'}, {'name': '1月7日', 'label': 'Thing'}, {'name': '平成', 'label': 'Thing'}, {'name': '1989年', 'label': 'Thing'}, {'name': '1月8日', 'label': 'Thing'}, {'name': '2019年', 'label': 'Thing'}, {'name': '4月30日', 'label': 'Thing'}, {'name': '内閣総理大臣', 'label': 'Thing'}, {'name': '竹下登', 'label': 'Person'}, {'name': '宇野宗佑', 'label': 'Person'}, {'name': '海部俊樹', 'label': 'Person'}, {'name': '宮澤喜一', 'label': 'Person'}, {'name': '細川護熙', 'label': 'Person'}, {'name': '羽田孜', 'label': 'Person'}, {'name': '村山富市', 'label': 'Person'}, {'name': '橋本龍太郎', 'label': 'Person'}, {'name': '小渕恵三', 'label': 'Person'}, {'name': '森喜朗', 'label': 'Person'}, {'name': '小泉純一郎', 'label': 'Person'}, {'name': '安倍晋三', 'label': 'Thing'}, {'name': '福田康夫', 'label': 'Person'}, {'name': '麻生太郎', 'label': 'Person'}, {'name': '鳩山由紀夫', 'label': 'Person'}, {'name': '菅直人', 'label': 'Person'}, {'name': '野田佳彦', 'label': 'Person'}, {'name': '安倍晋三', 'label': 'Thing'}, {'name': '昭和天皇', 'label': 'Person'}, {'name': '徳仁', 'label': 'Thing'}, {'name': '1933年', 'label': 'Thing'}, {'name': '12月23日', 'label': 'Thing'}, {'name': '午前6時', 'label': 'Thing'}, {'name': '39分', 'label': 'Thing'}, {'name': '日本', 'label': 'Country'}, {'name': '東京府', 'label': 'Organization'}, {'name': '東京市', 'label': 'Thing'}, {'name': '麹町', 'label': 'Thing'}, {'name': '宮城', 'label': 'Area'}, {'name': '殿', 'label': 'Area'}, {'name': '1933年', 'label': 'Thing'}, {'name': '12月29日', 'label': 'Thing'}, {'name': '1952年', 'label': 'Thing'}, {'name': '11月10日', 'label': 'Thing'}, {'name': '昭和天皇', 'label': 'Person'}, {'name': '香淳皇后', 'label': 'Person'}, {'name': '1959年', 'label': 'Thing'}, {'name': '4月10日', 'label': 'Thing'}, {'name': '徳仁', 'label': 'Thing'}, {'name': '秋篠宮文仁親王', 'label': 'Person'}, {'name': '黒田清子', 'label': 'Person'}, {'name': '皇太子徳仁親王', 'label': 'Thing'}, {'name': '東京都千代田区千代田', 'label': 'Area'}, {'name': '-1', 'label': 'Thing'}, {'name': '大勲位', 'label': 'Thing'}, {'name': '1952年', 'label': 'Thing'}, {'name': '学習院高等科', 'label': 'Thing'}, {'name': '1954年', 'label': 'Thing'}, {'name': '学習院大学', 'label': 'Organization'}, {'name': '政治経済学部', 'label': 'Thing'}, {'name': '2年', 'label': 'Thing'}, {'name': '中途退学', 'label': 'Thing'}, {'name': '魚類学', 'label': 'Thing'}, {'name': '日本', 'label': 'Country'}, {'name': '光格天皇', 'label': 'Person'}, {'name': '202年', 'label': 'Thing'}, {'name': 'Emperor', 'label': 'Person'}, {'name': 'Emeritus', 'label': 'Organization'}, {'name': '徳仁', 'label': 'Thing'}, {'name': '敬宮', 'label': 'Thing'}, {'name': '愛子内親王', 'label': 'Thing'}, {'name': '上皇后', 'label': 'Person'}, {'name': '親王妃', 'label': 'Thing'}, {'name': '眞子内親王', 'label': 'Person'}, {'name': '佳子内親王', 'label': 'Person'}, {'name': '悠仁親王', 'label': 'Person'}, {'name': '親王妃', 'label': 'Thing'}, {'name': '三笠宮', 'label': 'Person'}, {'name': '崇仁親王', 'label': 'Thing'}, {'name': '百合', 'label': 'Area'}, {'name': '寛仁親王', 'label': 'Thing'}, {'name': '彬子女王', 'label': 'Person'}, {'name': '瑶子女王', 'label': 'Perso ...

# %%
# Test
repo = Neo4jRepository(NEO4J_URL, NEO4J_ID, NEO4J_PW)
for node in node_origins:
    print(node)
    repo.create_node(node['name'], node['label'])
    #repo.delete_node(node['name'], node['label'])
# Out:
# {'name': 'Wikipedia', 'label': 'Thing'}
# {'name': '百科事典', 'label': 'Thing'}
# {'name': 'ウィキペディア', 'label': 'Thing'}
# {'name': 'ナビゲーション', 'label': 'Thing'}
# {'name': '2014年', 'label': 'Thing'}
# {'name': '4月24日', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '昭和64年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '午前6時', 'label': 'Thing'}
# {'name': '33分', 'label': 'Thing'}
# {'name': '平成31年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '12時', 'label': 'Thing'}
# {'name': '即位礼', 'label': 'Thing'}
# {'name': '即位礼正殿の儀', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '11月12日', 'label': 'Thing'}
# {'name': '大嘗宮の儀', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '11月22日', 'label': 'Thing'}
# {'name': '23日', 'label': 'Thing'}
# {'name': '東御苑', 'label': 'Area'}
# {'name': '大嘗宮', 'label': 'Thing'}
# {'name': '昭和', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月8日', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '内閣総理大臣', 'label': 'Thing'}
# {'name': '竹下登', 'label': 'Person'}
# {'name': '宇野宗佑', 'label': 'Person'}
# {'name': '海部俊樹', 'label': 'Person'}
# {'name': '宮澤喜一', 'label': 'Person'}
# {'name': '細川護熙', 'label': 'Person'}
# {'name': '羽田孜', 'label': 'Person'}
# {'name': '村山富市', 'label': 'Person'}
# {'name': '橋本龍太郎', 'label': 'Person'}
# {'name': '小渕恵三', 'label': 'Person'}
# {'name': '森喜朗', 'label': 'Person'}
# {'name': '小泉純一郎', 'label': 'Person'}
# {'name': '安倍晋三', 'label': 'Thing'}
# {'name': '福田康夫', 'label': 'Person'}
# {'name': '麻生太郎', 'label': 'Person'}
# {'name': '鳩山由紀夫', 'label': 'Person'}
# {'name': '菅直人', 'label': 'Person'}
# {'name': '野田佳彦', 'label': 'Person'}
# {'name': '安倍晋三', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '徳仁', 'label': 'Thing'}
# {'name': '1933年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '午前6時', 'label': 'Thing'}
# {'name': '39分', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '東京府', 'label': 'Organization'}
# {'name': '東京市', 'label': 'Thing'}
# {'name': '麹町', 'label': 'Thing'}
# {'name': '宮城', 'label': 'Area'}
# {'name': '殿', 'label': 'Area'}
# {'name': '1933年', 'label': 'Thing'}
# {'name': '12月29日', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '11月10日', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '1959年', 'label': 'Thing'}
# {'name': '4月10日', 'label': 'Thing'}
# {'name': '徳仁', 'label': 'Thing'}
# {'name': '秋篠宮文仁親王', 'label': 'Person'}
# {'name': '黒田清子', 'label': 'Person'}
# {'name': '皇太子徳仁親王', 'label': 'Thing'}
# {'name': '東京都千代田区千代田', 'label': 'Area'}
# {'name': '-1', 'label': 'Thing'}
# {'name': '大勲位', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '学習院高等科', 'label': 'Thing'}
# {'name': '1954年', 'label': 'Thing'}
# {'name': '学習院大学', 'label': 'Organization'}
# {'name': '政治経済学部', 'label': 'Thing'}
# {'name': '2年', 'label': 'Thing'}
# {'name': '中途退学', 'label': 'Thing'}
# {'name': '魚類学', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '光格天皇', 'label': 'Person'}
# {'name': '202年', 'label': 'Thing'}
# {'name': 'Emperor', 'label': 'Person'}
# {'name': 'Emeritus', 'label': 'Organization'}
# {'name': '徳仁', 'label': 'Thing'}
# {'name': '敬宮', 'label': 'Thing'}
# {'name': '愛子内親王', 'label': 'Thing'}
# {'name': '上皇后', 'label': 'Person'}
# {'name': '親王妃', 'label': 'Thing'}
# {'name': '眞子内親王', 'label': 'Person'}
# {'name': '佳子内親王', 'label': 'Person'}
# {'name': '悠仁親王', 'label': 'Person'}
# {'name': '親王妃', 'label': 'Thing'}
# {'name': '三笠宮', 'label': 'Person'}
# {'name': '崇仁親王', 'label': 'Thing'}
# {'name': '百合', 'label': 'Area'}
# {'name': '寛仁親王', 'label': 'Thing'}
# {'name': '彬子女王', 'label': 'Person'}
# {'name': '瑶子女王', 'label': 'Person'}
# {'name': '承子女王', 'label': 'Person'}
# {'name': '黄櫨染御袍', 'label': 'Thing'}
# {'name': '立', 'label': 'Area'}
# {'name': '即位礼正殿の儀', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '11月12日', 'label': 'Thing'}
# {'name': 'あきひと', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '繼宮', 'label': 'Organization'}
# {'name': 'お印', 'label': 'Thing'}
# {'name': '大勲位菊花章頸飾', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '日本国憲法', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '以', 'label': 'Organization'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '吹上御苑', 'label': 'Thing'}
# {'name': '仙洞御所', 'label': 'Area'}
# {'name': '構成員', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '皇位継承', 'label': 'Thing'}
# {'name': '幼少時代', 'label': 'Thing'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '天皇即位', 'label': 'Thing'}
# {'name': '天皇即位', 'label': 'Thing'}
# {'name': '日産自動車', 'label': 'Organization'}
# {'name': '日本の栄典', 'label': 'Thing'}
# {'name': '9.', 'label': 'Thing'}
# {'name': '9.', 'label': 'Thing'}
# {'name': '世界各国', 'label': 'Thing'}
# {'name': '参考文献', 'label': 'Thing'}
# {'name': '1933年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '東京府', 'label': 'Organization'}
# {'name': '東京市', 'label': 'Thing'}
# {'name': '麹町', 'label': 'Thing'}
# {'name': '宮城', 'label': 'Area'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '第五子', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '18歳', 'label': 'Thing'}
# {'name': '1959年', 'label': 'Thing'}
# {'name': '浩宮', 'label': 'Person'}
# {'name': '礼宮', 'label': 'Person'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '200回', 'label': 'Thing'}
# {'name': '20件', 'label': 'Thing'}
# {'name': '宮中祭祀', 'label': 'Thing'}
# {'name': '2015年', 'label': 'Thing'}
# {'name': '皇太子徳仁親王', 'label': 'Thing'}
# {'name': '秋篠宮文仁親王', 'label': 'Person'}
# {'name': '天皇の退位等に関する皇室典範特例法', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '令和元年', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '上皇后', 'label': 'Person'}
# {'name': '日本', 'label': 'Country'}
# {'name': '科学者', 'label': 'Thing'}
# {'name': '魚類学', 'label': 'Thing'}
# {'name': '分類学', 'label': 'Thing'}
# {'name': '日本魚類学会', 'label': 'Organization'}
# {'name': '学会誌', 'label': 'Thing'}
# {'name': '1992年', 'label': 'Thing'}
# {'name': 'Science', 'label': 'Organization'}
# {'name': '2000年', 'label': 'Thing'}
# {'name': '2008年', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '日本国外', 'label': 'Thing'}
# {'name': 'Gene', 'label': 'Person'}
# {'name': '魚類学', 'label': 'Thing'}
# {'name': '1980年', 'label': 'Thing'}
# {'name': '英国', 'label': 'Country'}
# {'name': 'ロンドン・リンネ協会', 'label': 'Organization'}
# {'name': '1986年', 'label': 'Thing'}
# {'name': '名誉会員', 'label': 'Thing'}
# {'name': 'オーストラリア', 'label': 'Country'}
# {'name': 'ロンドン動物学会', 'label': 'Thing'}
# {'name': '名誉会員', 'label': 'Thing'}
# {'name': 'アルゼンチン', 'label': 'Country'}
# {'name': '科学研究所', 'label': 'Thing'}
# {'name': '名誉会員', 'label': 'Thing'}
# {'name': '1998年', 'label': 'Thing'}
# {'name': '英国', 'label': 'Country'}
# {'name': 'ロンドン', 'label': 'Area'}
# {'name': '王立協会', 'label': 'Thing'}
# {'name': '2世', 'label': 'Thing'}
# {'name': '2007年', 'label': 'Thing'}
# {'name': '欧州', 'label': 'Area'}
# {'name': 'スウェーデン', 'label': 'Country'}
# {'name': 'ウプサラ', 'label': 'Thing'}
# {'name': '分類学', 'label': 'Thing'}
# {'name': '1992年', 'label': 'Thing'}
# {'name': 'Platygobiopsis', 'label': 'Organization'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': 'Exyrias', 'label': 'Organization'}
# {'name': '2007年', 'label': 'Thing'}
# {'name': 'アキヒト', 'label': 'Thing'}
# {'name': '献名', 'label': 'Thing'}
# {'name': '中国', 'label': 'Country'}
# {'name': '魚類学', 'label': 'Thing'}
# {'name': '民族学者', 'label': 'Thing'}
# {'name': '梅棹忠夫', 'label': 'Person'}
# {'name': '1971年', 'label': 'Thing'}
# {'name': '8月26日', 'label': 'Thing'}
# {'name': 'Astrabe', 'label': 'Organization'}
# {'name': 'et', 'label': 'Thing'}
# {'name': 'Astrabe', 'label': 'Organization'}
# {'name': 'fascia', 'label': 'Thing'}
# {'name': 'ta', 'label': 'Thing'}
# {'name': 'et', 'label': 'Thing'}
# {'name': 'Cristatogobius', 'label': 'Organization'}
# {'name': 'et', 'label': 'Thing'}
# {'name': 'Glossogobius', 'label': 'Organization'}
# {'name': 'et', 'label': 'Thing'}
# {'name': 'クロオビ', 'label': 'Thing'}
# {'name': 'Myersina', 'label': 'Organization'}
# {'name': 'et', 'label': 'Thing'}
# {'name': 'ミツボシゴマハゼ', 'label': 'Thing'}
# {'name': 'Pandaka', 'label': 'Organization'}
# {'name': 'et', 'label': 'Thing'}
# {'name': '幼少時代', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '1934年', 'label': 'Thing'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '継', 'label': 'Area'}
# {'name': '1933年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '午前6時', 'label': 'Thing'}
# {'name': '39分', 'label': 'Thing'}
# {'name': '宮城', 'label': 'Area'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '第5子', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '明治3年', 'label': 'Thing'}
# {'name': '1月3日', 'label': 'Thing'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': 'お印', 'label': 'Thing'}
# {'name': '北原白秋', 'label': 'Person'}
# {'name': '中山晋平', 'label': 'Person'}
# {'name': '1936年', 'label': 'Thing'}
# {'name': '3月29日', 'label': 'Thing'}
# {'name': '伝統的', 'label': 'Thing'}
# {'name': '2歳', 'label': 'Thing'}
# {'name': '赤坂離宮', 'label': 'Thing'}
# {'name': '1か月', 'label': 'Thing'}
# {'name': '1940年', 'label': 'Thing'}
# {'name': '学習院初等科', 'label': 'Organization'}
# {'name': '学習院', 'label': 'Thing'}
# {'name': '山梨勝之進', 'label': 'Person'}
# {'name': '内舎人', 'label': 'Thing'}
# {'name': '1941年', 'label': 'Thing'}
# {'name': '12月8日', 'label': 'Person'}
# {'name': '学習院初等科', 'label': 'Organization'}
# {'name': '2年', 'label': 'Thing'}
# {'name': '日米開戦', 'label': 'Thing'}
# {'name': '学習院初等科', 'label': 'Organization'}
# {'name': '5年', 'label': 'Thing'}
# {'name': '1944年', 'label': 'Thing'}
# {'name': '第二次世界大戦', 'label': 'Thing'}
# {'name': '栃木県日光市', 'label': 'Area'}
# {'name': '澤', 'label': 'Area'}
# {'name': '奥日光', 'label': 'Area'}
# {'name': '1945年', 'label': 'Thing'}
# {'name': '8月15日', 'label': 'Thing'}
# {'name': '玉音放送', 'label': 'Thing'}
# {'name': '1946年', 'label': 'Thing'}
# {'name': '10月', 'label': 'Thing'}
# {'name': '1950年', 'label': 'Thing'}
# {'name': '12月', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '教育方針', 'label': 'Thing'}
# {'name': 'アメリカ合衆国', 'label': 'Country'}
# {'name': '児童文学', 'label': 'Thing'}
# {'name': 'エリザベス・ヴァイニング', 'label': 'Person'}
# {'name': '家庭教師', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '11月10日', 'label': 'Thing'}
# {'name': '立太子の礼', 'label': 'Thing'}
# {'name': '皇太子成年式', 'label': 'Thing'}
# {'name': '大勲位', 'label': 'Thing'}
# {'name': '菊花大綬章', 'label': 'Thing'}
# {'name': '1953年', 'label': 'Thing'}
# {'name': '3月30日', 'label': 'Thing'}
# {'name': '10月12日', 'label': 'Thing'}
# {'name': 'ヨーロッパ', 'label': 'Area'}
# {'name': 'アメリカ合衆国', 'label': 'Country'}
# {'name': 'カナダ', 'label': 'Country'}
# {'name': '6月2日', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '英国', 'label': 'Country'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '2007年', 'label': 'Thing'}
# {'name': '学習院大学', 'label': 'Organization'}
# {'name': '12月', 'label': 'Thing'}
# {'name': '1957年', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '3月', 'label': 'Thing'}
# {'name': '60回', 'label': 'Thing'}
# {'name': '全国大会', 'label': 'Thing'}
# {'name': '1957年', 'label': 'Thing'}
# {'name': '8月19日', 'label': 'Thing'}
# {'name': '軽井沢', 'label': 'Area'}
# {'name': '日清製粉グループ', 'label': 'Thing'}
# {'name': '正田英三郎', 'label': 'Person'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '作品展', 'label': 'Thing'}
# {'name': '女ともだち', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '侍従長', 'label': 'Thing'}
# {'name': '入江相政', 'label': 'Person'}
# {'name': '入江相政日記', 'label': 'Thing'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '秩父宮妃勢津子', 'label': 'Thing'}
# {'name': '高松宮', 'label': 'Person'}
# {'name': '親王妃', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '1959年', 'label': 'Thing'}
# {'name': '1月14日', 'label': 'Thing'}
# {'name': '納采の儀', 'label': 'Thing'}
# {'name': '4月10日', 'label': 'Thing'}
# {'name': '明治以降', 'label': 'Thing'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': '2人', 'label': 'Thing'}
# {'name': '生中継', 'label': 'Thing'}
# {'name': '一般家庭', 'label': 'Thing'}
# {'name': '祝典行進曲', 'label': 'Thing'}
# {'name': '7月15日', 'label': 'Thing'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': '第一子', 'label': 'Thing'}
# {'name': '1960年', 'label': 'Thing'}
# {'name': '2月23日', 'label': 'Thing'}
# {'name': '第1子', 'label': 'Thing'}
# {'name': '浩宮', 'label': 'Person'}
# {'name': '3月', 'label': 'Thing'}
# {'name': '島津久永', 'label': 'Person'}
# {'name': '9月22日', 'label': 'Thing'}
# {'name': '10月7日', 'label': 'Thing'}
# {'name': '日', 'label': 'Country'}
# {'name': '米', 'label': 'Country'}
# {'name': '100周年', 'label': 'Thing'}
# {'name': 'アメリカ合衆国', 'label': 'Country'}
# {'name': '16日間', 'label': 'Thing'}
# {'name': '1965年', 'label': 'Thing'}
# {'name': '11月30日', 'label': 'Thing'}
# {'name': '第2子', 'label': 'Thing'}
# {'name': '礼宮', 'label': 'Person'}
# {'name': '1969年', 'label': 'Thing'}
# {'name': '4月18日', 'label': 'Thing'}
# {'name': '第3子', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '立太子の礼', 'label': 'Thing'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '立太子の礼', 'label': 'Thing'}
# {'name': '1955年', 'label': 'Thing'}
# {'name': '11月', 'label': 'Thing'}
# {'name': 'エチオピア皇帝', 'label': 'Thing'}
# {'name': 'ハイレ・セラシエ1世', 'label': 'Thing'}
# {'name': '1960年', 'label': 'Thing'}
# {'name': '日', 'label': 'Country'}
# {'name': '米', 'label': 'Country'}
# {'name': '100周年', 'label': 'Thing'}
# {'name': '晩餐会', 'label': 'Thing'}
# {'name': '1987年', 'label': 'Thing'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '3年後', 'label': 'Thing'}
# {'name': '1975年', 'label': 'Thing'}
# {'name': '沖縄国際海洋博覧会', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '大正', 'label': 'Thing'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '記録映画', 'label': 'Thing'}
# {'name': '記録映画', 'label': 'Thing'}
# {'name': '沖縄', 'label': 'Area'}
# {'name': '開会式', 'label': 'Thing'}
# {'name': '閉会式', 'label': 'Thing'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '7月17日', 'label': 'Thing'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': 'ひめゆりの塔', 'label': 'Thing'}
# {'name': '過激派', 'label': 'Thing'}
# {'name': '2人', 'label': 'Thing'}
# {'name': '1本', 'label': 'Thing'}
# {'name': '政治団体', 'label': 'Thing'}
# {'name': '全日本学生自治会総連合', 'label': 'Thing'}
# {'name': '1000人', 'label': 'Thing'}
# {'name': '沖縄', 'label': 'Area'}
# {'name': '沖縄', 'label': 'Area'}
# {'name': '琉歌', 'label': 'Thing'}
# {'name': '琉歌', 'label': 'Thing'}
# {'name': '1976年', 'label': 'Thing'}
# {'name': '1月18日', 'label': 'Thing'}
# {'name': '閉会式', 'label': 'Thing'}
# {'name': '1987年', 'label': 'Thing'}
# {'name': '沖縄', 'label': 'Area'}
# {'name': '海邦', 'label': 'Area'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '沖縄', 'label': 'Area'}
# {'name': '10月24日', 'label': 'Thing'}
# {'name': '西銘順治', 'label': 'Person'}
# {'name': '沖縄県知事', 'label': 'Thing'}
# {'name': '天皇即位', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '3位', 'label': 'Thing'}
# {'name': '55歳', 'label': 'Thing'}
# {'name': '皇位継承', 'label': 'Thing'}
# {'name': '8日', 'label': 'Thing'}
# {'name': '元号法', 'label': 'Thing'}
# {'name': '9日', 'label': 'Thing'}
# {'name': '即位後朝見の儀', 'label': 'Thing'}
# {'name': 'との', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '即位の礼', 'label': 'Thing'}
# {'name': '京都御所', 'label': 'Area'}
# {'name': '11月12日', 'label': 'Thing'}
# {'name': '即位礼正殿の儀', 'label': 'Thing'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '即位の礼', 'label': 'Thing'}
# {'name': '京都御所', 'label': 'Thing'}
# {'name': '関東', 'label': 'Area'}
# {'name': '即位の礼', 'label': 'Thing'}
# {'name': '祝賀御列の儀', 'label': 'Thing'}
# {'name': '赤坂御所', 'label': 'Area'}
# {'name': '7km', 'label': 'Thing'}
# {'name': '12万人', 'label': 'Thing'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '11月22日', 'label': 'Thing'}
# {'name': '23日', 'label': 'Thing'}
# {'name': '1992年', 'label': 'Thing'}
# {'name': '10月', 'label': 'Thing'}
# {'name': '中華人民共和国', 'label': 'Country'}
# {'name': '日中関係', 'label': 'Thing'}
# {'name': '中国大陸', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '中国外交部長', 'label': 'Thing'}
# {'name': '銭其シン', 'label': 'Person'}
# {'name': '回顧録', 'label': 'Thing'}
# {'name': '1999年', 'label': 'Thing'}
# {'name': '10周年', 'label': 'Thing'}
# {'name': '11月20日', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '10年', 'label': 'Thing'}
# {'name': '1993年', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': 'ひめゆり学徒隊', 'label': 'Organization'}
# {'name': '2003年', 'label': 'Thing'}
# {'name': '47都道府県', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '11月12日', 'label': 'Thing'}
# {'name': '記念式典', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '12月15日', 'label': 'Thing'}
# {'name': '習近平', 'label': 'Person'}
# {'name': '中華人民共和国副主席', 'label': 'Thing'}
# {'name': '1か月', 'label': 'Thing'}
# {'name': '羽毛田信吾', 'label': 'Person'}
# {'name': '宮内庁長官', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '民主党政権', 'label': 'Thing'}
# {'name': '鳩山由紀夫内閣', 'label': 'Thing'}
# {'name': '2011年', 'label': 'Thing'}
# {'name': '3月16日', 'label': 'Thing'}
# {'name': '東北地方太平洋沖地震', 'label': 'Thing'}
# {'name': '被災者', 'label': 'Thing'}
# {'name': 'ビデオメッセージ', 'label': 'Thing'}
# {'name': '剣璽等承継の儀', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月7日', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '大嘗宮', 'label': 'Thing'}
# {'name': '即位礼', 'label': 'Thing'}
# {'name': '祝賀御列の儀', 'label': 'Thing'}
# {'name': '饗宴の儀', 'label': 'Thing'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': '6月28日', 'label': 'Thing'}
# {'name': '米国', 'label': 'Country'}
# {'name': 'サイパン島', 'label': 'Thing'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': '11月22日', 'label': 'Thing'}
# {'name': 'ロシア大統領', 'label': 'Thing'}
# {'name': 'ウラジーミル・プーチン', 'label': 'Person'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '7月10日', 'label': 'Thing'}
# {'name': 'カナダ', 'label': 'Country'}
# {'name': 'ブリティッシュコロンビア州', 'label': 'Thing'}
# {'name': '2014年', 'label': 'Thing'}
# {'name': '4月24日', 'label': 'Thing'}
# {'name': 'アメリカ合衆国', 'label': 'Country'}
# {'name': 'バラク・オバマ', 'label': 'Person'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '1月2日', 'label': 'Thing'}
# {'name': '一般参賀', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '7月13日', 'label': 'Thing'}
# {'name': 'NHK', 'label': 'Thing'}
# {'name': '毎日新聞', 'label': 'Organization'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '関係者', 'label': 'Thing'}
# {'name': '数年', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '山本信一郎', 'label': 'Person'}
# {'name': '8月8日', 'label': 'Thing'}
# {'name': '11分間', 'label': 'Thing'}
# {'name': '象徴としてのお務めについての天皇陛下のおことば', 'label': 'Thing'}
# {'name': '2017年', 'label': 'Thing'}
# {'name': '12月1日', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '8日', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月1日', 'label': 'Thing'}
# {'name': '元号法', 'label': 'Thing'}
# {'name': '新元号', 'label': 'Thing'}
# {'name': '元号を改める政令', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '2月24日', 'label': 'Thing'}
# {'name': '60周年', 'label': 'Thing'}
# {'name': '4月10日', 'label': 'Thing'}
# {'name': '午後5時', 'label': 'Thing'}
# {'name': '国事行為', 'label': 'Thing'}
# {'name': '退位礼正殿の儀', 'label': 'Thing'}
# {'name': '正殿松の間', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '午前0時', 'label': 'Thing'}
# {'name': '以', 'label': 'Organization'}
# {'name': '皇太子徳仁親王', 'label': 'Thing'}
# {'name': '天皇の退位等に関する皇室典範特例法', 'label': 'Thing'}
# {'name': '第三条', 'label': 'Thing'}
# {'name': '喪儀', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '2017年', 'label': 'Thing'}
# {'name': '6月9日', 'label': 'Thing'}
# {'name': '参議院', 'label': 'Organization'}
# {'name': '本会議', 'label': 'Thing'}
# {'name': '天皇の退位等に関する皇室典範特例法', 'label': 'Thing'}
# {'name': '7日', 'label': 'Thing'}
# {'name': '16日', 'label': 'Thing'}
# {'name': '皇太子徳仁親王', 'label': 'Thing'}
# {'name': '1868年', 'label': 'Thing'}
# {'name': '一世一元の制', 'label': 'Thing'}
# {'name': '2017年', 'label': 'Thing'}
# {'name': '12月1日', 'label': 'Thing'}
# {'name': '皇室会議', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '徳仁', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '元号法', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '1989年', 'label': 'Thing'}
# {'name': '1月8日', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '皇位継承', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '上皇后', 'label': 'Person'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月1日', 'label': 'Thing'}
# {'name': '新元号', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '情報システム', 'label': 'Thing'}
# {'name': '2018年', 'label': 'Thing'}
# {'name': 'カレンダー', 'label': 'Thing'}
# {'name': '令和元年', 'label': 'Thing'}
# {'name': '5月1日', 'label': 'Thing'}
# {'name': '85歳', 'label': 'Thing'}
# {'name': '上皇后', 'label': 'Person'}
# {'name': '日本', 'label': 'Country'}
# {'name': '喪儀', 'label': 'Thing'}
# {'name': '大喪の礼', 'label': 'Thing'}
# {'name': '1938年', 'label': 'Thing'}
# {'name': '幼少期', 'label': 'Thing'}
# {'name': 'MGM', 'label': 'Thing'}
# {'name': '1953年', 'label': 'Thing'}
# {'name': '1953年', 'label': 'Thing'}
# {'name': '6月2日', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '英国', 'label': 'Country'}
# {'name': '3月30日', 'label': 'Thing'}
# {'name': '10月12日', 'label': 'Thing'}
# {'name': '横浜港', 'label': 'Area'}
# {'name': '100万人', 'label': 'Thing'}
# {'name': '放送局', 'label': 'Organization'}
# {'name': '大型客船', 'label': 'Thing'}
# {'name': 'プレジデント・ウィルソン', 'label': 'Thing'}
# {'name': '三島由紀夫', 'label': 'Person'}
# {'name': '2年前', 'label': 'Thing'}
# {'name': 'ハワイ', 'label': 'Area'}
# {'name': 'イギリス', 'label': 'Country'}
# {'name': '第二次世界大戦', 'label': 'Thing'}
# {'name': '1953年', 'label': 'Thing'}
# {'name': '6月2日', 'label': 'Thing'}
# {'name': 'ウェストミンスター寺院', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '戴冠式', 'label': 'Thing'}
# {'name': '13番', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '日本', 'label': 'Country'}
# {'name': '4日', 'label': 'Thing'}
# {'name': '6月6日', 'label': 'Thing'}
# {'name': 'エプソム競馬場', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '戦間期', 'label': 'Thing'}
# {'name': '日英同盟', 'label': 'Thing'}
# {'name': 'ジョージ5世', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '日英', 'label': 'Thing'}
# {'name': '学習院大学', 'label': 'Organization'}
# {'name': '政治学科', 'label': 'Thing'}
# {'name': 'クラブ活動', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '学習院高等科', 'label': 'Thing'}
# {'name': '政治学科', 'label': 'Thing'}
# {'name': '両国高校', 'label': 'Thing'}
# {'name': '日本会議国会議員懇談会', 'label': 'Thing'}
# {'name': '初代会長', 'label': 'Thing'}
# {'name': '島村宜伸', 'label': 'Person'}
# {'name': '1956年', 'label': 'Thing'}
# {'name': '3月', 'label': 'Thing'}
# {'name': '39年', 'label': 'Thing'}
# {'name': '5か月', 'label': 'Thing'}
# {'name': '1995年', 'label': 'Thing'}
# {'name': '8月', 'label': 'Thing'}
# {'name': '改造内閣', 'label': 'Thing'}
# {'name': '文部大臣', 'label': 'Thing'}
# {'name': '1959年', 'label': 'Thing'}
# {'name': '4月10日', 'label': 'Thing'}
# {'name': '記念切手', 'label': 'Thing'}
# {'name': '4種', 'label': 'Thing'}
# {'name': '10円', 'label': 'Thing'}
# {'name': '30円', 'label': 'Thing'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': '郵政省', 'label': 'Organization'}
# {'name': '1960年', 'label': 'Thing'}
# {'name': '米国', 'label': 'Country'}
# {'name': 'シカゴ市長', 'label': 'Thing'}
# {'name': 'ミシシッピ川', 'label': 'Thing'}
# {'name': 'ブルーギル', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '水産庁', 'label': 'Organization'}
# {'name': 'ブルーギル', 'label': 'Thing'}
# {'name': '在来種', 'label': 'Thing'}
# {'name': '水生昆虫', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '生態系', 'label': 'Thing'}
# {'name': '2007年', 'label': 'Thing'}
# {'name': '滋賀県大津市', 'label': 'Area'}
# {'name': '全国豊かな海づくり大会', 'label': 'Thing'}
# {'name': '天皇即位', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '相続税', 'label': 'Thing'}
# {'name': '4億', 'label': 'Thing'}
# {'name': '2800万円', 'label': 'Thing'}
# {'name': '千代田区', 'label': 'Area'}
# {'name': '住民税', 'label': 'Thing'}
# {'name': '1991年', 'label': 'Thing'}
# {'name': '雲仙普賢岳', 'label': 'Thing'}
# {'name': '被災地', 'label': 'Thing'}
# {'name': '被災者', 'label': 'Thing'}
# {'name': '一般国民', 'label': 'Thing'}
# {'name': '昭和', 'label': 'Thing'}
# {'name': '被災地', 'label': 'Thing'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '2008年', 'label': 'Thing'}
# {'name': '9月8日', 'label': 'Thing'}
# {'name': '新潟県中越地震', 'label': 'Thing'}
# {'name': '被災地', 'label': 'Thing'}
# {'name': '山古志村', 'label': 'Thing'}
# {'name': '中越地震', 'label': 'Thing'}
# {'name': '4日', 'label': 'Thing'}
# {'name': '2002年', 'label': 'Thing'}
# {'name': '2月20日', 'label': 'Thing'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': '6月28日', 'label': 'Thing'}
# {'name': 'サイパン島', 'label': 'Thing'}
# {'name': '2008年', 'label': 'Thing'}
# {'name': '11月8日', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '2011年', 'label': 'Thing'}
# {'name': '3月11日', 'label': 'Thing'}
# {'name': '東北地方太平洋沖地震', 'label': 'Thing'}
# {'name': '避難所', 'label': 'Thing'}
# {'name': '2013年', 'label': 'Thing'}
# {'name': '4月15日', 'label': 'Thing'}
# {'name': '2日', 'label': 'Thing'}
# {'name': '長野県千曲市', 'label': 'Area'}
# {'name': '7月', 'label': 'Thing'}
# {'name': '福島県', 'label': 'Area'}
# {'name': '2回', 'label': 'Thing'}
# {'name': '2014年', 'label': 'Thing'}
# {'name': '5月', 'label': 'Thing'}
# {'name': '栃木県', 'label': 'Area'}
# {'name': '渡良瀬遊水地', 'label': 'Thing'}
# {'name': '9月', 'label': 'Thing'}
# {'name': '青森県八戸市', 'label': 'Area'}
# {'name': '2015年', 'label': 'Thing'}
# {'name': '6月', 'label': 'Thing'}
# {'name': '宮城県', 'label': 'Area'}
# {'name': '刈田', 'label': 'Area'}
# {'name': '蔵王町', 'label': 'Area'}
# {'name': '原尾', 'label': 'Area'}
# {'name': '7月', 'label': 'Thing'}
# {'name': '福島県', 'label': 'Area'}
# {'name': '公営住宅', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '11月', 'label': 'Thing'}
# {'name': '愛知県', 'label': 'Area'}
# {'name': '入鹿池', 'label': 'Thing'}
# {'name': '2017年', 'label': 'Thing'}
# {'name': '9月', 'label': 'Thing'}
# {'name': '埼玉県日高市', 'label': 'Area'}
# {'name': '高麗神社', 'label': 'Area'}
# {'name': '渋沢栄一', 'label': 'Person'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '東京都千代田区', 'label': 'Area'}
# {'name': '天皇誕生日', 'label': 'Thing'}
# {'name': '一般参賀', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '7月15日', 'label': 'Thing'}
# {'name': '米国', 'label': 'Country'}
# {'name': 'ハワイ', 'label': 'Area'}
# {'name': 'ホノルル', 'label': 'Area'}
# {'name': '2010年', 'label': 'Thing'}
# {'name': '1月2日', 'label': 'Thing'}
# {'name': '東京都千代田区', 'label': 'Area'}
# {'name': '一般参賀', 'label': 'Thing'}
# {'name': '学習院高等科', 'label': 'Thing'}
# {'name': '3年', 'label': 'Thing'}
# {'name': '橋本明', 'label': 'Person'}
# {'name': '3人', 'label': 'Thing'}
# {'name': '東京', 'label': 'Area'}
# {'name': '銀座', 'label': 'Area'}
# {'name': '99円', 'label': 'Thing'}
# {'name': '高等科', 'label': 'Thing'}
# {'name': '藤島泰輔', 'label': 'Person'}
# {'name': '発売前', 'label': 'Thing'}
# {'name': '映画化', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': 'ミッチー・ブーム', 'label': 'Thing'}
# {'name': '民主化', 'label': 'Thing'}
# {'name': '日本社会党', 'label': 'Organization'}
# {'name': '江田三郎', 'label': 'Person'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '経済学者', 'label': 'Person'}
# {'name': '関根友彦', 'label': 'Person'}
# {'name': '学習院初等科', 'label': 'Organization'}
# {'name': '靖国神社', 'label': 'Organization'}
# {'name': '5回', 'label': 'Thing'}
# {'name': '靖国神社', 'label': 'Organization'}
# {'name': '南部利昭', 'label': 'Person'}
# {'name': 'との', 'label': 'Thing'}
# {'name': 'テレビ番組', 'label': 'Thing'}
# {'name': '暴れん坊将軍', 'label': 'Thing'}
# {'name': '水木しげる', 'label': 'Person'}
# {'name': '千代田区', 'label': 'Thing'}
# {'name': '2011年', 'label': 'Thing'}
# {'name': '3月11日', 'label': 'Thing'}
# {'name': '東北地方太平洋沖地震', 'label': 'Thing'}
# {'name': '計画停電', 'label': 'Thing'}
# {'name': '対象外', 'label': 'Thing'}
# {'name': '計画停電', 'label': 'Thing'}
# {'name': '計画停電', 'label': 'Thing'}
# {'name': '2011年', 'label': 'Thing'}
# {'name': '7月29日', 'label': 'Thing'}
# {'name': '8月10日', 'label': 'Thing'}
# {'name': 'アメリカ', 'label': 'Country'}
# {'name': '調査会社', 'label': 'Thing'}
# {'name': 'AP通信', 'label': 'Thing'}
# {'name': '日本全国', 'label': 'Thing'}
# {'name': '1000人', 'label': 'Thing'}
# {'name': '世論調査', 'label': 'Thing'}
# {'name': '70%', 'label': 'Thing'}
# {'name': 'オバマ', 'label': 'Thing'}
# {'name': '米国大統領', 'label': 'Thing'}
# {'name': '1位', 'label': 'Thing'}
# {'name': '1949年', 'label': 'Thing'}
# {'name': '節子', 'label': 'Area'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '1952年', 'label': 'Thing'}
# {'name': '正仁親王', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '2代目', 'label': 'Thing'}
# {'name': 'インテグラ', 'label': 'Thing'}
# {'name': '1953年', 'label': 'Thing'}
# {'name': 'アルファロメオ', 'label': 'Organization'}
# {'name': '所有者', 'label': 'Thing'}
# {'name': '助手席', 'label': 'Thing'}
# {'name': '後部座席', 'label': 'Thing'}
# {'name': '2018年', 'label': 'Thing'}
# {'name': '1991年製', 'label': 'Thing'}
# {'name': 'ホンダ・インテグラ', 'label': 'Thing'}
# {'name': '2007年', 'label': 'Thing'}
# {'name': '3年', 'label': 'Thing'}
# {'name': '高齢者', 'label': 'Thing'}
# {'name': '運転免許', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': 'カナダ', 'label': 'Country'}
# {'name': 'ビクトリア', 'label': 'Area'}
# {'name': '軍用機', 'label': 'Thing'}
# {'name': 'コクピット', 'label': 'Thing'}
# {'name': 'ビクトリア', 'label': 'Person'}
# {'name': 'バンクーバー', 'label': 'Area'}
# {'name': '空軍機', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': 'カナダ', 'label': 'Country'}
# {'name': '日産自動車', 'label': 'Organization'}
# {'name': '1954年', 'label': 'Thing'}
# {'name': 'プリンス・セダン', 'label': 'Thing'}
# {'name': '国産車', 'label': 'Thing'}
# {'name': '1954年', 'label': 'Thing'}
# {'name': 'プリンス自動車', 'label': 'Thing'}
# {'name': 'プリンス・セダン', 'label': 'Thing'}
# {'name': 'ホンダ・インテグラ', 'label': 'Thing'}
# {'name': '高級車', 'label': 'Thing'}
# {'name': '100mm', 'label': 'Thing'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': '公用車', 'label': 'Thing'}
# {'name': '1990年', 'label': 'Thing'}
# {'name': '11月12日', 'label': 'Thing'}
# {'name': '即位礼正殿の儀', 'label': 'Thing'}
# {'name': '1998年', 'label': 'Thing'}
# {'name': '12月18日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2001年', 'label': 'Thing'}
# {'name': '12月18日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '韓国', 'label': 'Country'}
# {'name': '桓武天皇', 'label': 'Person'}
# {'name': '2003年', 'label': 'Thing'}
# {'name': '12月18日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '島津家', 'label': 'Thing'}
# {'name': '島津家', 'label': 'Thing'}
# {'name': '薩摩藩', 'label': 'Thing'}
# {'name': '江戸時代', 'label': 'Thing'}
# {'name': '琉球侵攻', 'label': 'Thing'}
# {'name': '沖縄県', 'label': 'Area'}
# {'name': '琉球王国', 'label': 'Thing'}
# {'name': '実質的', 'label': 'Thing'}
# {'name': '2004年', 'label': 'Thing'}
# {'name': '10月28日', 'label': 'Thing'}
# {'name': '秋の園遊会', 'label': 'Thing'}
# {'name': '東京都', 'label': 'Area'}
# {'name': '教育委員', 'label': 'Thing'}
# {'name': '米長邦雄', 'label': 'Person'}
# {'name': '人格否定発言', 'label': 'Thing'}
# {'name': '2004年', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '2005年', 'label': 'Thing'}
# {'name': '12月19日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '代表質問', 'label': 'Thing'}
# {'name': '2006年', 'label': 'Thing'}
# {'name': '6月6日', 'label': 'Thing'}
# {'name': 'シンガポール', 'label': 'Country'}
# {'name': 'タイ王国', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2006年', 'label': 'Thing'}
# {'name': '12月20日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2008年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '4月8日', 'label': 'Thing'}
# {'name': '50年', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': '11月11日', 'label': 'Thing'}
# {'name': '20年', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2012年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2013年', 'label': 'Thing'}
# {'name': '12月23日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '8月8日', 'label': 'Thing'}
# {'name': '2018年', 'label': 'Thing'}
# {'name': '12月20日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '記者会見', 'label': 'Thing'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '4月30日', 'label': 'Thing'}
# {'name': '退位礼正殿の儀', 'label': 'Thing'}
# {'name': 'おことば', 'label': 'Thing'}
# {'name': '公共放送', 'label': 'Thing'}
# {'name': 'NHK', 'label': 'Thing'}
# {'name': '2016年', 'label': 'Thing'}
# {'name': '2003年', 'label': 'Thing'}
# {'name': '1月', 'label': 'Thing'}
# {'name': '前立腺がん', 'label': 'Thing'}
# {'name': '2008年', 'label': 'Thing'}
# {'name': '12月', 'label': 'Thing'}
# {'name': '2011年', 'label': 'Thing'}
# {'name': '11月', 'label': 'Thing'}
# {'name': '2012年', 'label': 'Thing'}
# {'name': '3月', 'label': 'Thing'}
# {'name': 'ガーター騎士団', 'label': 'Thing'}
# {'name': '金羊毛騎士団', 'label': 'Thing'}
# {'name': 'セラフィム', 'label': 'Thing'}
# {'name': '騎士団', 'label': 'Thing'}
# {'name': '日本の栄典', 'label': 'Thing'}
# {'name': '大勲位菊花章頸飾', 'label': 'Thing'}
# {'name': '勲一等旭日桐花大綬章', 'label': 'Thing'}
# {'name': '瑞宝大綬章', 'label': 'Thing'}
# {'name': '文化勲章', 'label': 'Thing'}
# {'name': '日本赤十字', 'label': 'Thing'}
# {'name': '特別社員', 'label': 'Thing'}
# {'name': '日本赤十字社金色有功章', 'label': 'Thing'}
# {'name': 'アフガニスタン', 'label': 'Country'}
# {'name': 'オーストリア', 'label': 'Country'}
# {'name': 'オーストリア共和国', 'label': 'Thing'}
# {'name': 'バーレーン', 'label': 'Country'}
# {'name': 'ハリーファ', 'label': 'Thing'}
# {'name': 'ベルギー', 'label': 'Country'}
# {'name': 'ボツワナ', 'label': 'Country'}
# {'name': 'ブラジル', 'label': 'Country'}
# {'name': 'カンボジア', 'label': 'Country'}
# {'name': 'カンボジア', 'label': 'Country'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'カメルーン', 'label': 'Country'}
# {'name': 'チリ', 'label': 'Country'}
# {'name': 'コロンビア', 'label': 'Country'}
# {'name': 'コートジボワール', 'label': 'Country'}
# {'name': 'コートジボワール', 'label': 'Country'}
# {'name': 'チェコ', 'label': 'Country'}
# {'name': '頸飾', 'label': 'Organization'}
# {'name': 'デンマーク', 'label': 'Country'}
# {'name': 'エレファント', 'label': 'Thing'}
# {'name': 'エジプト', 'label': 'Country'}
# {'name': 'ナイル勲章', 'label': 'Thing'}
# {'name': 'エストニア', 'label': 'Country'}
# {'name': 'テッラ・マリアナ十字勲章', 'label': 'Thing'}
# {'name': 'エチオピア帝国', 'label': 'Thing'}
# {'name': 'ソロモン勲章', 'label': 'Person'}
# {'name': 'フィンランド', 'label': 'Country'}
# {'name': 'フィンランド白薔薇勲章', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'フランス', 'label': 'Country'}
# {'name': 'レジオンドヌール勲章', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'ガンビア', 'label': 'Country'}
# {'name': 'ガンビア', 'label': 'Country'}
# {'name': '共和国勲章', 'label': 'Thing'}
# {'name': 'ドイツ', 'label': 'Country'}
# {'name': 'ドイツ連邦共和国功労勲章', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'ギリシャ', 'label': 'Country'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'ハンガリー', 'label': 'Country'}
# {'name': 'ハンガリー共和国', 'label': 'Thing'}
# {'name': 'Grand', 'label': 'Organization'}
# {'name': 'Cross', 'label': 'Thing'}
# {'name': 'with', 'label': 'Person'}
# {'name': 'Chain', 'label': 'Organization'}
# {'name': 'アイスランド', 'label': 'Country'}
# {'name': 'ファルコン', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'インドネシア', 'label': 'Country'}
# {'name': 'Star', 'label': 'Organization'}
# {'name': 'st', 'label': 'Thing'}
# {'name': 'Class', 'label': 'Thing'}
# {'name': 'アイルランド', 'label': 'Country'}
# {'name': 'ダブリン', 'label': 'Area'}
# {'name': 'イタリア', 'label': 'Country'}
# {'name': 'イタリア共和国功労勲章', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'ヨルダン', 'label': 'Country'}
# {'name': 'ビン', 'label': 'Organization'}
# {'name': 'カザフスタン', 'label': 'Country'}
# {'name': 'ケニア', 'label': 'Country'}
# {'name': 'ケニア', 'label': 'Country'}
# {'name': 'クウェート', 'label': 'Country'}
# {'name': 'ムバーラク', 'label': 'Thing'}
# {'name': 'ラトビア', 'label': 'Country'}
# {'name': '三星', 'label': 'Organization'}
# {'name': 'Command', 'label': 'Thing'}
# {'name': 'er', 'label': 'Thing'}
# {'name': 'Cross', 'label': 'Thing'}
# {'name': 'with', 'label': 'Person'}
# {'name': 'Chain', 'label': 'Organization'}
# {'name': 'リベリア', 'label': 'Country'}
# {'name': 'アフリカ', 'label': 'Area'}
# {'name': 'Knight', 'label': 'Thing'}
# {'name': 'リベリア', 'label': 'Country'}
# {'name': '開拓者', 'label': 'Thing'}
# {'name': 'リトアニア', 'label': 'Country'}
# {'name': 'ヴィータウタス', 'label': 'Thing'}
# {'name': 'ルクセンブルク', 'label': 'Country'}
# {'name': 'ナッサウ家', 'label': 'Thing'}
# {'name': 'マラウイ', 'label': 'Country'}
# {'name': 'マレーシア', 'label': 'Country'}
# {'name': 'Honorary', 'label': 'Organization'}
# {'name': 'Crown', 'label': 'Thing'}
# {'name': 'マリ', 'label': 'Country'}
# {'name': 'マリ', 'label': 'Country'}
# {'name': 'メキシコ', 'label': 'Country'}
# {'name': 'アステカ', 'label': 'Thing'}
# {'name': 'モロッコ', 'label': 'Country'}
# {'name': 'ムハンマド', 'label': 'Thing'}
# {'name': 'ネパール', 'label': 'Country'}
# {'name': 'Order', 'label': 'Organization'}
# {'name': 'Member', 'label': 'Organization'}
# {'name': 'King', 'label': 'Person'}
# {'name': 'Birendra', 'label': 'Organization'}
# {'name': 'オランダ', 'label': 'Country'}
# {'name': 'オランダ', 'label': 'Country'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'ナイジェリア', 'label': 'Country'}
# {'name': 'Order', 'label': 'Organization'}
# {'name': 'Grand', 'label': 'Organization'}
# {'name': 'Command', 'label': 'Thing'}
# {'name': 'er', 'label': 'Thing'}
# {'name': 'ノルウェー', 'label': 'Country'}
# {'name': '聖オーラヴ勲章', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'オマーン', 'label': 'Country'}
# {'name': 'オマーン', 'label': 'Country'}
# {'name': 'パキスタン', 'label': 'Country'}
# {'name': 'Nishan', 'label': 'Organization'}
# {'name': 'e', 'label': 'Organization'}
# {'name': 'Pakistan', 'label': 'Thing'}
# {'name': 'st', 'label': 'Thing'}
# {'name': 'Class', 'label': 'Thing'}
# {'name': 'パナマ', 'label': 'Country'}
# {'name': 'Order', 'label': 'Organization'}
# {'name': 'Gold', 'label': 'Person'}
# {'name': 'Collar', 'label': 'Organization'}
# {'name': 'ペルー', 'label': 'Country'}
# {'name': 'Order', 'label': 'Organization'}
# {'name': 'Sun', 'label': 'Thing'}
# {'name': 'Grand', 'label': 'Organization'}
# {'name': 'Cross', 'label': 'Thing'}
# {'name': 'フィリピン', 'label': 'Country'}
# {'name': 'Philippine', 'label': 'Thing'}
# {'name': 'Chief', 'label': 'Organization'}
# {'name': 'Command', 'label': 'Thing'}
# {'name': 'er', 'label': 'Thing'}
# {'name': 'Grand', 'label': 'Organization'}
# {'name': 'ポーランド', 'label': 'Country'}
# {'name': 'ポルトガル', 'label': 'Country'}
# {'name': 'サンティアゴ', 'label': 'Area'}
# {'name': 'エンリケ航海王子勲章', 'label': 'Thing'}
# {'name': 'カタール', 'label': 'Country'}
# {'name': 'Collar', 'label': 'Organization'}
# {'name': 'サウジアラビア', 'label': 'Country'}
# {'name': 'Badr', 'label': 'Organization'}
# {'name': 'セネガル', 'label': 'Country'}
# {'name': 'Order', 'label': 'Organization'}
# {'name': 'Lion', 'label': 'Organization'}
# {'name': 'Collar', 'label': 'Organization'}
# {'name': '南アフリカ', 'label': 'Country'}
# {'name': '喜望峰', 'label': 'Area'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'スペイン', 'label': 'Country'}
# {'name': '金羊毛', 'label': 'Thing'}
# {'name': 'カルロス3世', 'label': 'Thing'}
# {'name': '大十字章', 'label': 'Thing'}
# {'name': 'カルロス3世', 'label': 'Thing'}
# {'name': 'スウェーデン', 'label': 'Country'}
# {'name': 'セラフィム', 'label': 'Thing'}
# {'name': 'Knight', 'label': 'Person'}
# {'name': 'with', 'label': 'Person'}
# {'name': 'Collar', 'label': 'Organization'}
# {'name': 'タイ', 'label': 'Country'}
# {'name': 'on', 'label': 'Thing'}
# {'name': '60t', 'label': 'Thing'}
# {'name': 'Anniversary', 'label': 'Thing'}
# {'name': 'H.M.', 'label': 'Thing'}
# {'name': 'King', 'label': 'Person'}
# {'name': 'Bhumibol', 'label': 'Organization'}
# {'name': 'ウクライナ', 'label': 'Country'}
# {'name': 'ヤロスラフ', 'label': 'Thing'}
# {'name': '賢公', 'label': 'Thing'}
# {'name': 'アラブ首長国連邦', 'label': 'Thing'}
# {'name': 'イギリス', 'label': 'Country'}
# {'name': 'ガーター勲章', 'label': 'Thing'}
# {'name': '外国人', 'label': 'Thing'}
# {'name': 'ヴィクトリア', 'label': 'Thing'}
# {'name': 'グランド・クロス', 'label': 'Person'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': '戴冠式', 'label': 'Thing'}
# {'name': 'ユーゴスラビア', 'label': 'Country'}
# {'name': 'ユーゴ', 'label': 'Country'}
# {'name': 'スラブ', 'label': 'Area'}
# {'name': 'ザイール', 'label': 'Country'}
# {'name': 'National', 'label': 'Thing'}
# {'name': 'Leopard', 'label': 'Thing'}
# {'name': 'Grand', 'label': 'Organization'}
# {'name': '明治', 'label': 'Thing'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '秩父宮雍仁親王', 'label': 'Person'}
# {'name': '高松宮宣仁親王', 'label': 'Person'}
# {'name': '三笠宮崇仁親王', 'label': 'Person'}
# {'name': '常陸宮正仁親王', 'label': 'Person'}
# {'name': '寛仁親王', 'label': 'Thing'}
# {'name': '桂宮宜仁親王', 'label': 'Person'}
# {'name': '高円宮憲仁親王', 'label': 'Person'}
# {'name': '今上天皇', 'label': 'Thing'}
# {'name': '秋篠宮文仁親王', 'label': 'Person'}
# {'name': '悠仁親王', 'label': 'Person'}
# {'name': '孝明天皇', 'label': 'Person'}
# {'name': '明治', 'label': 'Thing'}
# {'name': '中山慶子', 'label': 'Person'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '柳原光愛', 'label': 'Thing'}
# {'name': '9.', 'label': 'Thing'}
# {'name': '柳原愛子', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '九条尚忠', 'label': 'Person'}
# {'name': '九条道孝', 'label': 'Person'}
# {'name': '唐橋姪子', 'label': 'Person'}
# {'name': '九条節子', 'label': 'Person'}
# {'name': '伏見宮邦家親王', 'label': 'Person'}
# {'name': '久邇宮朝彦親王', 'label': 'Person'}
# {'name': '久邇宮邦彦王', 'label': 'Person'}
# {'name': '13.', 'label': 'Thing'}
# {'name': '久邇宮', 'label': 'Person'}
# {'name': '島津久光', 'label': 'Person'}
# {'name': '島津忠義', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': '柳原愛子', 'label': 'Person'}
# {'name': '貞明皇后', 'label': 'Person'}
# {'name': '九条道孝', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '朝彦親王', 'label': 'Person'}
# {'name': '島津忠義', 'label': 'Person'}
# {'name': '孝明天皇', 'label': 'Person'}
# {'name': '中山慶子', 'label': 'Person'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': '柳原愛子', 'label': 'Person'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '貞明皇后', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '香淳皇后', 'label': 'Person'}
# {'name': '久邇宮朝融王', 'label': 'Person'}
# {'name': '久邇邦久', 'label': 'Person'}
# {'name': '三条西信子', 'label': 'Person'}
# {'name': '大谷智子', 'label': 'Person'}
# {'name': '東伏見慈洽', 'label': 'Person'}
# {'name': '皇位継承', 'label': 'Thing'}
# {'name': '皇統譜', 'label': 'Thing'}
# {'name': '北朝', 'label': 'Organization'}
# {'name': '神武天皇', 'label': 'Thing'}
# {'name': '綏靖天皇', 'label': 'Thing'}
# {'name': '安寧天皇', 'label': 'Person'}
# {'name': '懿徳天皇', 'label': 'Thing'}
# {'name': '孝昭天皇', 'label': 'Thing'}
# {'name': '孝安天皇', 'label': 'Thing'}
# {'name': '孝元天皇', 'label': 'Thing'}
# {'name': '開化天皇', 'label': 'Thing'}
# {'name': '崇神天皇', 'label': 'Thing'}
# {'name': '垂仁天皇', 'label': 'Thing'}
# {'name': '景行天皇', 'label': 'Thing'}
# {'name': '日本武尊', 'label': 'Thing'}
# {'name': '仲哀天皇', 'label': 'Thing'}
# {'name': '応神天皇', 'label': 'Person'}
# {'name': '野毛', 'label': 'Area'}
# {'name': '意富富杼王', 'label': 'Thing'}
# {'name': '乎非王', 'label': 'Thing'}
# {'name': '彦主人王', 'label': 'Thing'}
# {'name': '継体天皇', 'label': 'Person'}
# {'name': '欽明天皇', 'label': 'Person'}
# {'name': '敏達天皇', 'label': 'Person'}
# {'name': '押坂彦人大兄皇子', 'label': 'Thing'}
# {'name': '舒明天皇', 'label': 'Person'}
# {'name': '天智天皇', 'label': 'Person'}
# {'name': '志貴皇子', 'label': 'Person'}
# {'name': '光仁天皇', 'label': 'Person'}
# {'name': '桓武天皇', 'label': 'Person'}
# {'name': '嵯峨天皇', 'label': 'Person'}
# {'name': '仁明天皇', 'label': 'Person'}
# {'name': '光孝天皇', 'label': 'Person'}
# {'name': '宇多天皇', 'label': 'Person'}
# {'name': '醍醐天皇', 'label': 'Person'}
# {'name': '村上天皇', 'label': 'Person'}
# {'name': '円融天皇', 'label': 'Person'}
# {'name': '後朱雀天皇', 'label': 'Person'}
# {'name': '後三条天皇', 'label': 'Person'}
# {'name': '白河天皇', 'label': 'Person'}
# {'name': '堀河天皇', 'label': 'Person'}
# {'name': '鳥羽天皇', 'label': 'Person'}
# {'name': '後白河天皇', 'label': 'Person'}
# {'name': '高倉天皇', 'label': 'Person'}
# {'name': '後鳥羽天皇', 'label': 'Person'}
# {'name': '土御門天皇', 'label': 'Person'}
# {'name': '後嵯峨天皇', 'label': 'Person'}
# {'name': '後深草天皇', 'label': 'Person'}
# {'name': '伏見天皇', 'label': 'Person'}
# {'name': '後伏見天皇', 'label': 'Person'}
# {'name': '光厳天皇', 'label': 'Person'}
# {'name': '崇光天皇', 'label': 'Thing'}
# {'name': '栄仁親王', 'label': 'Thing'}
# {'name': '貞成親王', 'label': 'Thing'}
# {'name': '後花園天皇', 'label': 'Person'}
# {'name': '後土御門天皇', 'label': 'Person'}
# {'name': '後柏原天皇', 'label': 'Person'}
# {'name': '後奈良天皇', 'label': 'Person'}
# {'name': '正親町天皇', 'label': 'Person'}
# {'name': '誠仁親王', 'label': 'Person'}
# {'name': '後陽成天皇', 'label': 'Person'}
# {'name': '後水尾天皇', 'label': 'Person'}
# {'name': '霊元天皇', 'label': 'Person'}
# {'name': '東山天皇', 'label': 'Person'}
# {'name': '直仁親王', 'label': 'Person'}
# {'name': '典仁親王', 'label': 'Thing'}
# {'name': '光格天皇', 'label': 'Person'}
# {'name': '仁孝天皇', 'label': 'Person'}
# {'name': '孝明天皇', 'label': 'Person'}
# {'name': '明治', 'label': 'Thing'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '漢', 'label': 'Country'}
# {'name': '記紀', 'label': 'Thing'}
# {'name': '神武天皇', 'label': 'Thing'}
# {'name': '綏靖天皇', 'label': 'Thing'}
# {'name': '安寧天皇', 'label': 'Person'}
# {'name': '懿徳天皇', 'label': 'Thing'}
# {'name': '孝昭天皇', 'label': 'Thing'}
# {'name': '孝安天皇', 'label': 'Thing'}
# {'name': '孝元天皇', 'label': 'Thing'}
# {'name': '開化天皇', 'label': 'Thing'}
# {'name': '崇神天皇', 'label': 'Thing'}
# {'name': '彦坐王', 'label': 'Thing'}
# {'name': '紀元後', 'label': 'Thing'}
# {'name': '垂仁天皇', 'label': 'Thing'}
# {'name': '景行天皇', 'label': 'Thing'}
# {'name': '日本武尊', 'label': 'Thing'}
# {'name': '成務天皇', 'label': 'Thing'}
# {'name': '仲哀天皇', 'label': 'Thing'}
# {'name': '-2', 'label': 'Thing'}
# {'name': '神功皇后', 'label': 'Person'}
# {'name': '-3', 'label': 'Thing'}
# {'name': '仁徳天皇', 'label': 'Person'}
# {'name': '野毛', 'label': 'Area'}
# {'name': '履中天皇', 'label': 'Person'}
# {'name': '反正天皇', 'label': 'Thing'}
# {'name': '允恭天皇', 'label': 'Person'}
# {'name': '忍坂大中姫', 'label': 'Thing'}
# {'name': '意富富杼王', 'label': 'Thing'}
# {'name': '市辺押磐皇子', 'label': 'Thing'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '安康天皇', 'label': 'Person'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '雄略天皇', 'label': 'Person'}
# {'name': '乎非王', 'label': 'Thing'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '飯豊青皇女', 'label': 'Person'}
# {'name': '朝', 'label': 'Country'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '仁賢天皇', 'label': 'Person'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '-4', 'label': 'Thing'}
# {'name': '清寧天皇', 'label': 'Thing'}
# {'name': '彦主人王', 'label': 'Thing'}
# {'name': '武烈天皇', 'label': 'Thing'}
# {'name': '手白香皇女', 'label': 'Thing'}
# {'name': '欽明天皇', 'label': 'Person'}
# {'name': '安閑天皇', 'label': 'Person'}
# {'name': '宣化天皇', 'label': 'Person'}
# {'name': '敏達天皇', 'label': 'Person'}
# {'name': '額田部', 'label': 'Thing'}
# {'name': '推古天皇', 'label': 'Person'}
# {'name': '用明天皇', 'label': 'Person'}
# {'name': '泊', 'label': 'Area'}
# {'name': '瀬部', 'label': 'Area'}
# {'name': '崇峻天皇', 'label': 'Person'}
# {'name': '押坂彦人大兄皇子', 'label': 'Thing'}
# {'name': '厩戸皇子', 'label': 'Person'}
# {'name': '茅渟王', 'label': 'Thing'}
# {'name': '孝徳天皇', 'label': 'Person'}
# {'name': '皇極天皇', 'label': 'Thing'}
# {'name': '明天', 'label': 'Area'}
# {'name': '舒明天皇', 'label': 'Person'}
# {'name': '葛城', 'label': 'Area'}
# {'name': '天智天皇', 'label': 'Person'}
# {'name': '弘文天皇', 'label': 'Person'}
# {'name': '持統天皇', 'label': 'Person'}
# {'name': '天武天皇', 'label': 'Person'}
# {'name': '志貴皇子', 'label': 'Person'}
# ...
# {'name': '後奈良天皇', 'label': 'Person'}
# {'name': '正親町天皇', 'label': 'Person'}
# {'name': '江戸時代', 'label': 'Thing'}
# {'name': '後陽成天皇', 'label': 'Person'}
# {'name': '後水尾天皇', 'label': 'Person'}
# {'name': '明正天皇', 'label': 'Person'}
# {'name': '後光明天皇', 'label': 'Person'}
# {'name': '後西天皇', 'label': 'Person'}
# {'name': '霊元天皇', 'label': 'Person'}
# {'name': '東山天皇', 'label': 'Person'}
# {'name': '中御門天皇', 'label': 'Person'}
# {'name': '桜町天皇', 'label': 'Person'}
# {'name': '桃園天皇', 'label': 'Person'}
# {'name': '後桜町天皇', 'label': 'Person'}
# {'name': '後桃園天皇', 'label': 'Person'}
# {'name': '光格天皇', 'label': 'Person'}
# {'name': '仁孝天皇', 'label': 'Person'}
# {'name': '孝明天皇', 'label': 'Person'}
# {'name': '明治以降', 'label': 'Thing'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': '大正天皇', 'label': 'Person'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '徳仁', 'label': 'Thing'}
# {'name': '大正', 'label': 'Thing'}
# {'name': '神功皇后', 'label': 'Person'}
# {'name': '仲哀天皇', 'label': 'Thing'}
# {'name': '応神天皇', 'label': 'Person'}
# {'name': '37代', 'label': 'Thing'}
# {'name': '斉明天皇', 'label': 'Thing'}
# {'name': '35代', 'label': 'Thing'}
# {'name': '皇極天皇', 'label': 'Thing'}
# {'name': '48代', 'label': 'Thing'}
# {'name': '称徳天皇', 'label': 'Thing'}
# {'name': '46代', 'label': 'Thing'}
# {'name': '孝謙天皇', 'label': 'Thing'}
# {'name': '38代', 'label': 'Thing'}
# {'name': '天智天皇', 'label': 'Person'}
# {'name': '6年', 'label': 'Thing'}
# {'name': '称制', 'label': 'Thing'}
# {'name': '41代', 'label': 'Thing'}
# {'name': '持統天皇', 'label': 'Person'}
# {'name': '3年', 'label': 'Thing'}
# {'name': '称制', 'label': 'Thing'}
# {'name': '57代', 'label': 'Thing'}
# {'name': '陽成天皇', 'label': 'Person'}
# {'name': '事実上', 'label': 'Thing'}
# {'name': '81代', 'label': 'Thing'}
# {'name': '安徳天皇', 'label': 'Person'}
# {'name': '2年間', 'label': 'Thing'}
# {'name': '82代', 'label': 'Thing'}
# {'name': '後鳥羽天皇', 'label': 'Person'}
# {'name': '2年間', 'label': 'Thing'}
# {'name': '96代', 'label': 'Thing'}
# {'name': '後醍醐天皇', 'label': 'Person'}
# {'name': '2度', 'label': 'Thing'}
# {'name': '鎌倉時代', 'label': 'Thing'}
# {'name': '建武の新政', 'label': 'Thing'}
# {'name': '吉野', 'label': 'Area'}
# {'name': '3期', 'label': 'Thing'}
# {'name': '光厳天皇', 'label': 'Person'}
# {'name': '光明天皇', 'label': 'Person'}
# {'name': '光厳天皇', 'label': 'Person'}
# {'name': '北朝', 'label': 'Organization'}
# {'name': '光明天皇', 'label': 'Person'}
# {'name': '後醍醐天皇', 'label': 'Person'}
# {'name': '京都', 'label': 'Area'}
# {'name': '吉野', 'label': 'Thing'}
# {'name': '南朝', 'label': 'Organization'}
# {'name': '北朝', 'label': 'Organization'}
# {'name': '皇統譜', 'label': 'Thing'}
# {'name': '後小松天皇', 'label': 'Person'}
# {'name': '10年間', 'label': 'Thing'}
# {'name': '北朝', 'label': 'Organization'}
# {'name': '南北朝', 'label': 'Thing'}
# {'name': '20年間', 'label': 'Thing'}
# {'name': '100代', 'label': 'Thing'}
# {'name': '近現代', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': '第1世代', 'label': 'Thing'}
# {'name': '明治天皇', 'label': 'Person'}
# {'name': '第1世代', 'label': 'Thing'}
# {'name': '建宮敬仁親王', 'label': 'Person'}
# {'name': '明宮嘉仁親王', 'label': 'Thing'}
# {'name': '昭宮猷仁親王', 'label': 'Person'}
# {'name': '満宮輝仁親王', 'label': 'Person'}
# {'name': '有栖川宮威仁親王', 'label': 'Person'}
# {'name': '閑院宮', 'label': 'Thing'}
# {'name': '華頂宮博厚親王', 'label': 'Person'}
# {'name': '東伏見宮依仁親王', 'label': 'Person'}
# {'name': '第2世代', 'label': 'Thing'}
# {'name': '宮', 'label': 'Area'}
# {'name': '裕仁親王', 'label': 'Thing'}
# {'name': '雍仁親王', 'label': 'Person'}
# {'name': '宮', 'label': 'Area'}
# {'name': '崇仁親王', 'label': 'Thing'}
# {'name': '第3世代', 'label': 'Thing'}
# {'name': '継', 'label': 'Area'}
# {'name': '桂宮宜仁親王', 'label': 'Person'}
# {'name': '高円宮憲仁親王', 'label': 'Person'}
# {'name': '第4世代', 'label': 'Thing'}
# {'name': '浩宮', 'label': 'Person'}
# {'name': '礼宮', 'label': 'Person'}
# {'name': '第5世代', 'label': 'Thing'}
# {'name': '悠仁親王', 'label': 'Person'}
# {'name': '身位', 'label': 'Thing'}
# {'name': '今上天皇', 'label': 'Thing'}
# {'name': '后位', 'label': 'Thing'}
# {'name': '上皇后', 'label': 'Person'}
# {'name': '皇太子妃', 'label': 'Thing'}
# {'name': '親王妃', 'label': 'Thing'}
# {'name': '大妃', 'label': 'Thing'}
# {'name': '宮', 'label': 'Area'}
# {'name': '入道親王', 'label': 'Thing'}
# {'name': '太上法皇', 'label': 'Thing'}
# {'name': '准太上天皇', 'label': 'Thing'}
# {'name': '皇太妃', 'label': 'Thing'}
# {'name': '皇太妃', 'label': 'Thing'}
# {'name': '御匣殿別当', 'label': 'Thing'}
# {'name': '旧皇族', 'label': 'Thing'}
# {'name': '内廷皇族', 'label': 'Thing'}
# {'name': '直宮家', 'label': 'Thing'}
# {'name': '女性天皇', 'label': 'Thing'}
# {'name': '女系天皇', 'label': 'Thing'}
# {'name': '女性宮家', 'label': 'Thing'}
# {'name': '院宮王臣家', 'label': 'Thing'}
# {'name': '王公族', 'label': 'Thing'}
# {'name': '朝鮮貴族', 'label': 'Thing'}
# {'name': '臣籍降下', 'label': 'Thing'}
# {'name': '親王宣下', 'label': 'Thing'}
# {'name': '皇別', 'label': 'Thing'}
# {'name': '皇別摂家', 'label': 'Thing'}
# {'name': '皇位継承', 'label': 'Thing'}
# {'name': '皇位継承順位', 'label': 'Thing'}
# {'name': '御称号', 'label': 'Thing'}
# {'name': '宮号', 'label': 'Thing'}
# {'name': '全名', 'label': 'Thing'}
# {'name': 'お印', 'label': 'Thing'}
# {'name': '宮中祭祀', 'label': 'Thing'}
# {'name': '宮中三殿', 'label': 'Thing'}
# {'name': '皇霊殿', 'label': 'Thing'}
# {'name': '天照大神', 'label': 'Thing'}
# {'name': '皇祖神', 'label': 'Thing'}
# {'name': '伊勢神宮', 'label': 'Thing'}
# {'name': '日本神話', 'label': 'Thing'}
# {'name': '日本の元首', 'label': 'Thing'}
# {'name': '日本国憲法', 'label': 'Thing'}
# {'name': '国事行為', 'label': 'Thing'}
# {'name': '国事行為臨時代行', 'label': 'Thing'}
# {'name': '国事行為の臨時代行に関する法律', 'label': 'Thing'}
# {'name': '天皇の退位等に関する皇室典範特例法', 'label': 'Thing'}
# {'name': '皇室典範', 'label': 'Thing'}
# {'name': '皇室経済法', 'label': 'Thing'}
# {'name': '皇室経済会議', 'label': 'Thing'}
# {'name': '皇室経済法施行法', 'label': 'Thing'}
# {'name': '皇室会議', 'label': 'Thing'}
# {'name': '皇室財産', 'label': 'Thing'}
# {'name': '皇室費用', 'label': 'Thing'}
# {'name': '宮廷費', 'label': 'Thing'}
# {'name': '内廷費', 'label': 'Thing'}
# {'name': '皇族費', 'label': 'Thing'}
# {'name': '皇室令', 'label': 'Thing'}
# {'name': '皇室服喪令', 'label': 'Thing'}
# {'name': '宮内庁法', 'label': 'Organization'}
# {'name': '宮内庁御用達', 'label': 'Thing'}
# {'name': '最高敬語', 'label': 'Thing'}
# {'name': '永世皇族制', 'label': 'Thing'}
# {'name': '象徴天皇制', 'label': 'Thing'}
# {'name': '天皇制', 'label': 'Thing'}
# {'name': '皇室裁判所', 'label': 'Thing'}
# {'name': '皇族軍人', 'label': 'Thing'}
# {'name': '名誉総裁', 'label': 'Thing'}
# {'name': '皇室の儀式', 'label': 'Thing'}
# {'name': '即位の礼', 'label': 'Thing'}
# {'name': '大喪の礼', 'label': 'Thing'}
# {'name': '退位の礼', 'label': 'Thing'}
# {'name': '立太子の礼', 'label': 'Thing'}
# {'name': '立皇嗣の礼', 'label': 'Thing'}
# {'name': '講書始', 'label': 'Thing'}
# {'name': '歌会始', 'label': 'Thing'}
# {'name': '鴨場', 'label': 'Organization'}
# {'name': '打毬', 'label': 'Organization'}
# {'name': '信任状捧呈式', 'label': 'Thing'}
# {'name': '任命式', 'label': 'Thing'}
# {'name': '一般参賀', 'label': 'Thing'}
# {'name': '新年祝賀の儀', 'label': 'Thing'}
# {'name': '納采の儀', 'label': 'Thing'}
# {'name': '命名の儀', 'label': 'Thing'}
# {'name': '斂葬の儀', 'label': 'Thing'}
# {'name': '先帝祭', 'label': 'Thing'}
# {'name': '天皇誕生日', 'label': 'Thing'}
# {'name': '誕生日', 'label': 'Thing'}
# {'name': '鎮魂祭', 'label': 'Thing'}
# {'name': '招魂祭', 'label': 'Thing'}
# {'name': '元始祭', 'label': 'Thing'}
# {'name': '皇霊祭', 'label': 'Thing'}
# {'name': '歳旦祭', 'label': 'Thing'}
# {'name': '神武天皇祭', 'label': 'Thing'}
# {'name': '紀元二千六百年記念行事', 'label': 'Thing'}
# {'name': '三種の神器', 'label': 'Thing'}
# {'name': '八咫鏡', 'label': 'Thing'}
# {'name': '八尺瓊勾玉', 'label': 'Thing'}
# {'name': '天叢雲剣', 'label': 'Thing'}
# {'name': '正倉院', 'label': 'Area'}
# {'name': '三の丸尚蔵館', 'label': 'Organization'}
# {'name': '御府', 'label': 'Area'}
# {'name': '一期一振', 'label': 'Person'}
# {'name': '桂本万葉集', 'label': 'Thing'}
# {'name': '小烏丸', 'label': 'Thing'}
# {'name': '鶴丸', 'label': 'Area'}
# {'name': '唐本御影', 'label': 'Thing'}
# {'name': '平野藤四郎', 'label': 'Thing'}
# {'name': '流星刀', 'label': 'Thing'}
# {'name': '壺切御剣', 'label': 'Thing'}
# {'name': '鶯丸', 'label': 'Thing'}
# {'name': '京都御所', 'label': 'Area'}
# {'name': '大宮御所', 'label': 'Area'}
# {'name': '東宮御所', 'label': 'Thing'}
# {'name': '吹上御所', 'label': 'Thing'}
# {'name': '紅葉山御養蚕所', 'label': 'Area'}
# {'name': '仙洞御所', 'label': 'Area'}
# {'name': '比丘尼御所', 'label': 'Thing'}
# {'name': '桂離宮', 'label': 'Area'}
# {'name': '赤坂御用地', 'label': 'Area'}
# {'name': '赤坂離宮', 'label': 'Thing'}
# {'name': '修学院離宮', 'label': 'Thing'}
# {'name': '豊島岡墓地', 'label': 'Thing'}
# {'name': '明治宮殿', 'label': 'Area'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '掌侍', 'label': 'Thing'}
# {'name': '女孺', 'label': 'Thing'}
# {'name': '掌典職', 'label': 'Organization'}
# {'name': '皇后宮職', 'label': 'Organization'}
# {'name': '皇太后宮職', 'label': 'Thing'}
# {'name': '中宮職', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '侍従職', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '東宮職', 'label': 'Thing'}
# {'name': '東宮侍従', 'label': 'Thing'}
# {'name': '東宮大夫', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '上皇職', 'label': 'Thing'}
# {'name': '宮内庁', 'label': 'Organization'}
# {'name': '皇嗣職', 'label': 'Thing'}
# {'name': '皇宮警察本部', 'label': 'Organization'}
# {'name': '皇宮護衛官', 'label': 'Thing'}
# {'name': '菊栄親睦会', 'label': 'Thing'}
# {'name': '霞会館', 'label': 'Organization'}
# {'name': '内大臣府', 'label': 'Organization'}
# {'name': '帝室博物館', 'label': 'Organization'}
# {'name': '帝室林野局', 'label': 'Organization'}
# {'name': 'お召し列車', 'label': 'Thing'}
# {'name': '皇室用客車', 'label': 'Thing'}
# {'name': '御車', 'label': 'Thing'}
# {'name': '御料車', 'label': 'Thing'}
# {'name': '日産', 'label': 'Organization'}
# {'name': 'トヨタ・センチュリーロイヤル', 'label': 'Thing'}
# {'name': '泉涌寺', 'label': 'Thing'}
# {'name': '皇居外苑', 'label': 'Area'}
# {'name': '菊花紋章', 'label': 'Thing'}
# {'name': '学校法人学習院', 'label': 'Thing'}
# {'name': '天皇陛下万歳', 'label': 'Thing'}
# {'name': '明治神宮', 'label': 'Area'}
# {'name': 'ガーター騎士団', 'label': 'Thing'}
# {'name': 'エリザベス2世', 'label': 'Person'}
# {'name': 'プリンス・オブ・ウェールズ', 'label': 'Thing'}
# {'name': '7代', 'label': 'Thing'}
# {'name': 'アシュバートン', 'label': 'Thing'}
# {'name': 'サー', 'label': 'Person'}
# {'name': 'ティモシー', 'label': 'Person'}
# {'name': 'コールマン', 'label': 'Organization'}
# {'name': '5代', 'label': 'Thing'}
# {'name': 'イング', 'label': 'Thing'}
# {'name': 'バトラー', 'label': 'Person'}
# {'name': 'サー', 'label': 'Person'}
# {'name': 'ジョン・メージャー', 'label': 'Person'}
# {'name': 'フィリップス', 'label': 'Organization'}
# {'name': 'マニンガム＝ブラー', 'label': 'Thing'}
# {'name': '5代', 'label': 'Thing'}
# {'name': 'サー', 'label': 'Person'}
# {'name': 'デイヴィッド', 'label': 'Person'}
# {'name': '3代', 'label': 'Thing'}
# {'name': '7代', 'label': 'Thing'}
# {'name': 'ソールズベリー', 'label': 'Area'}
# {'name': 'エディンバラ', 'label': 'Area'}
# {'name': 'ケント公爵', 'label': 'Thing'}
# {'name': 'プリンセス・ロイヤル', 'label': 'Thing'}
# {'name': 'グロスター', 'label': 'Thing'}
# {'name': 'アレクサンドラ', 'label': 'Person'}
# {'name': 'ウェセックス伯爵', 'label': 'Thing'}
# {'name': 'ケンブリッジ公爵', 'label': 'Thing'}
# {'name': 'マルグレーテ2世', 'label': 'Thing'}
# {'name': 'フアン・カルロス', 'label': 'Thing'}
# {'name': '1世', 'label': 'Thing'}
# {'name': 'ベアトリクス', 'label': 'Thing'}
# {'name': 'ハーラル5世', 'label': 'Thing'}
# {'name': 'フェリペ6世', 'label': 'Thing'}
# {'name': 'ウィレム＝アレクサンダー', 'label': 'Thing'}
# {'name': 'オフィサー', 'label': 'Thing'}
# {'name': 'ウィンチェスター', 'label': 'Thing'}
# {'name': 'キン', 'label': 'Thing'}
# {'name': '5代', 'label': 'Thing'}
# {'name': 'ウィンザー', 'label': 'Area'}
# {'name': 'デイヴィッド', 'label': 'Person'}
# {'name': 'Garter', 'label': 'Organization'}
# {'name': 'King', 'label': 'Person'}
# {'name': 'of', 'label': 'Organization'}
# {'name': 'ディキンソン', 'label': 'Thing'}
# {'name': 'Black', 'label': 'Person'}
# {'name': 'Rod', 'label': 'Organization'}
# {'name': 'サラ・クラーク', 'label': 'Person'}
# {'name': '典拠管理', 'label': 'Thing'}
# {'name': 'XX', 'label': 'Organization'}
# {'name': 'CiNii', 'label': 'Thing'}
# {'name': 'DA', 'label': 'Thing'}
# {'name': 'GND', 'label': 'Thing'}
# {'name': 'n', 'label': 'Organization'}
# {'name': 'NDL', 'label': 'Thing'}
# {'name': 'xx', 'label': 'Organization'}
# {'name': 'NLA', 'label': 'Thing'}
# {'name': 'w', 'label': 'Organization'}
# {'name': '20世紀', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '21世紀', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '平成', 'label': 'Thing'}
# {'name': '日本', 'label': 'Country'}
# {'name': '昭和天皇', 'label': 'Person'}
# {'name': '大勲位菊花章頸飾', 'label': 'Thing'}
# {'name': '大勲位菊花大綬章', 'label': 'Thing'}
# {'name': '文化勲章', 'label': 'Thing'}
# {'name': 'ガーター勲章', 'label': 'Thing'}
# {'name': '金羊毛騎士団', 'label': 'Thing'}
# {'name': 'レジオンドヌール勲章', 'label': 'Thing'}
# {'name': 'グランクロワ', 'label': 'Thing'}
# {'name': 'ヴィクトリア', 'label': 'Thing'}
# {'name': 'ソロモン勲章', 'label': 'Person'}
# {'name': '日本', 'label': 'Country'}
# {'name': '日本の魚', 'label': 'Thing'}
# {'name': 'ロンドン・リンネ協会', 'label': 'Organization'}
# {'name': '大阪万博', 'label': 'Thing'}
# {'name': '東京都区部', 'label': 'Thing'}
# {'name': '1933年', 'label': 'Thing'}
# {'name': 'リンク切れ', 'label': 'Thing'}
# {'name': '2009年', 'label': 'Thing'}
# {'name': 'リンク切れ', 'label': 'Thing'}
# {'name': '2018年', 'label': 'Thing'}
# {'name': '6月', 'label': 'Thing'}
# {'name': 'リンク切れ', 'label': 'Thing'}
# {'name': '2017年', 'label': 'Thing'}
# {'name': '10月', 'label': 'Thing'}
# {'name': 'Web', 'label': 'Thing'}
# {'name': 'archive', 'label': 'Thing'}
# {'name': 'ウェイバック', 'label': 'Thing'}
# {'name': 'ISBN', 'label': 'Thing'}
# {'name': '2018年', 'label': 'Thing'}
# {'name': '11月', 'label': 'Thing'}
# {'name': 'GND', 'label': 'Thing'}
# {'name': 'NLA', 'label': 'Thing'}
# {'name': 'ID', 'label': 'Thing'}
# {'name': 'ツール', 'label': 'Area'}
# {'name': '名前空間', 'label': 'Thing'}
# {'name': '編集履歴', 'label': 'Thing'}
# {'name': 'アップロード', 'label': 'Thing'}
# {'name': 'ウィキペディア', 'label': 'Thing'}
# {'name': 'アップロード', 'label': 'Thing'}
# {'name': 'ウィキデータ', 'label': 'Thing'}
# {'name': '新規作成', 'label': 'Thing'}
# {'name': 'PDF', 'label': 'Thing'}
# {'name': 'AsturianuAz', 'label': 'Organization'}
# {'name': 'rbaycanca', 'label': 'Organization'}
# {'name': 'BaliŽemaitėška', 'label': 'Organization'}
# {'name': 'Български', 'label': 'Organization'}
# {'name': 'BosanskiCatalàMìng', 'label': 'Organization'}
# {'name': 'dĕ', 'label': 'Organization'}
# {'name': 'ng', 'label': 'Thing'}
# {'name': 'ngṳ', 'label': 'Organization'}
# {'name': 'C', 'label': 'Organization'}
# {'name': 'ors', 'label': 'Thing'}
# {'name': 'English', 'label': 'Thing'}
# {'name': 'Esperanto', 'label': 'Thing'}
# {'name': 'Suomi', 'label': 'Thing'}
# {'name': 'França', 'label': 'Thing'}
# {'name': 'is', 'label': 'Person'}
# {'name': 'ord', 'label': 'Person'}
# {'name': 'friiskGaeilgeGalegoHausa', 'label': 'Organization'}
# {'name': '客家語', 'label': 'Thing'}
# {'name': 'Hak', 'label': 'Organization'}
# {'name': 'kâ', 'label': 'Organization'}
# {'name': 'ngî', 'label': 'Organization'}
# {'name': 'HrvatskiMagyar', 'label': 'Organization'}
# {'name': 'Bahasa', 'label': 'Organization'}
# {'name': 'Indonesia', 'label': 'Thing'}
# {'name': 'Кыргызча', 'label': 'Organization'}
# {'name': 'Latina', 'label': 'Thing'}
# {'name': 'ze', 'label': 'Person'}
# {'name': 'bu', 'label': 'Thing'}
# {'name': 'erge', 'label': 'Thing'}
# {'name': 'sc', 'label': 'Thing'}
# {'name': 'Монгол', 'label': 'Organization'}
# {'name': 'Bahasa', 'label': 'Organization'}
# {'name': 'NederlandsNorsk', 'label': 'Organization'}
# {'name': 'ny', 'label': 'Thing'}
# {'name': 'nor', 'label': 'Thing'}
# {'name': 'sk', 'label': 'Person'}
# {'name': 'N', 'label': 'Organization'}
# {'name': 'ors', 'label': 'Thing'}
# {'name': 'PortuguêsRuna', 'label': 'Organization'}
# {'name': 'ic', 'label': 'Thing'}
# {'name': 'il', 'label': 'Thing'}
# {'name': 'ia', 'label': 'Person'}
# {'name': 'n', 'label': 'Organization'}
# {'name': 'ots', 'label': 'Thing'}
# {'name': 'Da', 'label': 'Thing'}
# {'name': 'vv', 'label': 'Thing'}
# {'name': 'српскохрватски', 'label': 'Organization'}
# {'name': 'Simple', 'label': 'Thing'}
# {'name': 's', 'label': 'Organization'}
# {'name': 'rp', 'label': 'Thing'}
# {'name': 'TagalogTürkçe', 'label': 'Organization'}
# {'name': 'tatarça', 'label': 'Organization'}
# {'name': 'O', 'label': 'Organization'}
# {'name': 'zbekcha', 'label': 'Organization'}
# {'name': 'ўзбекча', 'label': 'Organization'}
# {'name': 'Yorùbá', 'label': 'Organization'}
# {'name': '中文', 'label': 'Thing'}
# {'name': 'lâm', 'label': 'Organization'}
# {'name': 'gú', 'label': 'Organization'}
# {'name': '2019年', 'label': 'Thing'}
# {'name': '11月2日', 'label': 'Thing'}
# {'name': 'クリエイティブ・コモンズ', 'label': 'Organization'}
# {'name': '利用規約', 'label': 'Thing'}
# {'name': 'プライバシー・ポリシー', 'label': 'Thing'}
# {'name': 'ウィキペディア', 'label': 'Thing'}
# {'name': '開発者', 'label': 'Thing'}
# {'name': 'Cookie', 'label': 'Thing'}

# %%
import CaboCha
cabocha = CaboCha.Parser()

for sentence in lines:
    print(sentence)
#     tree = cabocha.parse(sentence)
#     print(tree.toString(CaboCha.CABOCHA_FORMAT_TREE))
#     break
